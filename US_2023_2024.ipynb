# %% [markdown]
# # Stock Closing Price Trends: 2023 vs 2024
#
# Compare daily closing prices for six tech stocks between 2023 and 2024 using `yfinance`.
#
# **Stocks:** NVDA, AAPL, TSLA, AMZN, MSFT, GOOGL
#
# **Workflow:**
# 1. Import libraries (`yfinance`, `pandas`, `matplotlib`)
# 2. Download 2023 & 2024 closing prices
# 3. Plot 2023 (solid) vs 2024 (dashed)

# %%
# !pip install yfinance

# Import libraries
import yfinance as yf
import pandas as pd
import matplotlib.pyplot as plt

# Define stock tickers
tickers = ['NVDA', 'AAPL', 'TSLA', 'AMZN', 'MSFT', 'GOOGL']

# Define date ranges
start_2023 = '2023-01-01'
end_2024 = '2024-01-01'
start_2024 = '2024-01-01'
end_2025 = '2025-01-01'

# Download 2023 data
data_2023 = yf.download(tickers, start=start_2023, end=end_2024)['Close']

# Download 2024 data
data_2024 = yf.download(tickers, start=start_2024, end=end_2025)['Close']

# Plot 2023 and 2024 closing prices
plt.figure(figsize=(16,8))

for ticker in tickers:
    plt.plot(data_2023.index, data_2023[ticker], label=f'{ticker} (2023)', linestyle='-')
    plt.plot(data_2024.index, data_2024[ticker], label=f'{ticker} (2024)', linestyle='--')

plt.title('Stock Closing Prices: 2023 vs 2024', fontsize=20)
plt.xlabel('Date', fontsize=14)
plt.ylabel('Closing Price (USD)', fontsize=14)
plt.legend()
plt.grid(True)
plt.show()
# Out:
# [*********************100%***********************]  6 of 6 completed
# Requirement already satisfied: yfinance in c:\users\cindy\anaconda3\lib\site-packages (0.2.56)
# Requirement already satisfied: pandas>=1.3.0 in c:\users\cindy\anaconda3\lib\site-packages (from yfinance) (2.2.2)
# Requirement already satisfied: numpy>=1.16.5 in c:\users\cindy\anaconda3\lib\site-packages (from yfinance) (1.26.4)
# Requirement already satisfied: requests>=2.31 in c:\users\cindy\anaconda3\lib\site-packages (from yfinance) (2.32.2)
# Requirement already satisfied: multitasking>=0.0.7 in c:\users\cindy\anaconda3\lib\site-packages (from yfinance) (0.0.11)
# Requirement already satisfied: platformdirs>=2.0.0 in c:\users\cindy\appdata\roaming\python\python312\site-packages (from yfinance) (4.2.2)
# Requirement already satisfied: pytz>=2022.5 in c:\users\cindy\anaconda3\lib\site-packages (from yfinance) (2024.1)
# Requirement already satisfied: frozendict>=2.3.4 in c:\users\cindy\anaconda3\lib\site-packages (from yfinance) (2.4.2)
# Requirement already satisfied: peewee>=3.16.2 in c:\users\cindy\anaconda3\lib\site-packages (from yfinance) (3.17.9)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in c:\users\cindy\anaconda3\lib\site-packages (from yfinance) (4.12.3)
# Requirement already satisfied: soupsieve>1.2 in c:\users\cindy\anaconda3\lib\site-packages (from beautifulsoup4>=4.11.1->yfinance) (2.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\cindy\appdata\roaming\python\python312\site-packages (from pandas>=1.3.0->yfinance) (2.9.0.post0)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\cindy\anaconda3\lib\site-packages (from pandas>=1.3.0->yfinance) (2023.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\cindy\anaconda3\lib\site-packages (from requests>=2.31->yfinance) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\cindy\anaconda3\lib\site-packages (from requests>=2.31->yfinance) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\cindy\anaconda3\lib\site-packages (from requests>=2.31->yfinance) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\cindy\anaconda3\lib\site-packages (from requests>=2.31->yfinance) (2024.8.30)
# Requirement already satisfied: six>=1.5 in c:\users\cindy\appdata\roaming\python\python312\site-packages (from python-dateutil>=2.8.2->pandas>=1.3.0->yfinance) (1.16.0)
# [*********************100%***********************]  6 of 6 completed

# %% [markdown]
# ## Calculate Annual Returns
#
# For each stock ticker, we compute year-over-year returns for 2023 and 2024 as:
#
# - **2023 Return (%)** = (last close in 2023 − first close in 2023) / first close in 2023 × 100
# - **2024 Return (%)** = (last close in 2024 − first close in 2024) / first close in 2024 × 100
#
# The results will be stored in a DataFrame for easy comparison.

# %%
returns = {}

for ticker in tickers:
    start_price_2023 = data_2023[ticker].iloc[0]
    end_price_2023 = data_2023[ticker].iloc[-1]
    return_2023 = (end_price_2023 - start_price_2023) / start_price_2023 * 100

    start_price_2024 = data_2024[ticker].iloc[0]
    end_price_2024 = data_2024[ticker].iloc[-1]
    return_2024 = (end_price_2024 - start_price_2024) / start_price_2024 * 100

    returns[ticker] = {'2023 Return (%)': return_2023, '2024 Return (%)': return_2024}

returns_df = pd.DataFrame(returns).T
returns_df = returns_df.round(2)

print(returns_df)
# Out:
#        2023 Return (%)  2024 Return (%)
# NVDA            246.10           178.87
# AAPL             54.80            35.56
# TSLA            129.86            62.56
# AMZN             77.04            46.33
# MSFT             58.35            14.50
# GOOGL            56.74            37.50

# %% [markdown]
# ## Plot Annual Returns Comparison
#
# Generate a grouped bar chart to compare each stock’s 2023 vs 2024 returns:
#
# - Use `returns_df.plot(kind='bar', figsize=(12,6))`
# - Add title, axis labels, grid and legend for clarity
# - Rotate x-ticks to improve readability

# %%
colors = ['#2ca02c', '#d62728']  

ax = returns_df.plot(
    kind='bar',
    figsize=(12,6),
    color=colors
)
ax.set_title('Stock Returns Comparison: 2023 vs 2024', fontsize=18)
ax.set_ylabel('Return (%)', fontsize=14)
ax.set_xlabel('Stock Ticker', fontsize=14)
ax.grid(axis='y', linestyle='--', alpha=0.5)
ax.legend(title='Year')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
